# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', 200)
pd.set_option('display.width', 300)

# %%
data = pd.read_csv("accepted_2007_to_2018Q4.csv", low_memory=False)
data.head()
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment grade sub_grade                    emp_title emp_length home_ownership  annual_inc verification_status   issue_d loan_status pymnt_plan                                                url desc  \
# 0  68407277        NaN     3600.0       3600.0           3600.0   36 months     13.99       123.03     C        C4                      leadman  10+ years       MORTGAGE     55000.0        Not Verified  Dec-2015  Fully Paid          n  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 1  68355089        NaN    24700.0      24700.0          24700.0   36 months     11.99       820.28     C        C1                     Engineer  10+ years       MORTGAGE     65000.0        Not Verified  Dec-2015  Fully Paid          n  https://lendingclub.com/browse/loanDetail.acti...  NaN
# ...

# %%
data.describe()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2260701 entries, 0 to 2260700
# Columns: 151 entries, id to settlement_term
# dtypes: float64(113), object(38)
# memory usage: 2.5+ GB

# %%
#Creating a copy of raw data file
data_v1 = data.copy()

# %%
# Explore main categorical value column to determine which "loan_status" data to include in ML dataset
data_v1.loan_status.value_counts()
# Out:
# Fully Paid                                             1076751
# Current                                                 878317
# Charged Off                                             268559
# Late (31-120 days)                                       21467
# In Grace Period                                           8436
# Late (16-30 days)                                         4349
# Does not meet the credit policy. Status:Fully Paid        1988
# Does not meet the credit policy. Status:Charged Off        761
# Default                                                     40
# Name: loan_status, dtype: int64

# %%
#Dropping all loan_status categories except  Fully Paid & Charged Off
data_v2 = data_v1.drop(data_v1[(data_v1['loan_status'] == 'Late (31-120 days)') | (data_v1['loan_status'] == 'In Grace Period') | (data_v1['loan_status'] == 'Late (16-30 days)') | (data_v1['loan_status'] == 'Does not meet the credit policy. Status:Fully Paid') | (data_v1['loan_status'] == 'Does not meet the credit policy. Status:Charged Off') | (data_v1['loan_status'] == 'Default') | (data_v1['loan_status'] == 'Current')].index)
data_v2
# Out:
#                                                        id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment grade sub_grade             emp_title emp_length home_ownership  annual_inc verification_status   issue_d  loan_status pymnt_plan  \
# 0                                                68407277        NaN     3600.0       3600.0           3600.0   36 months     13.99       123.03     C        C4               leadman  10+ years       MORTGAGE     55000.0        Not Verified  Dec-2015   Fully Paid          n
# 1                                                68355089        NaN    24700.0      24700.0          24700.0   36 months     11.99       820.28     C        C1              Engineer  10+ years       MORTGAGE     65000.0        Not Verified  Dec-2015   Fully Paid          n
# ...

# %%
data_v2.loan_status.value_counts()
# Out:
# Fully Paid     1076751
# Charged Off     268559
# Name: loan_status, dtype: int64

# %%
# Count sum of "na's" in each column -top 60-
data_v2.isna().sum().head(60)

# %%
# Count sum of "na's" in each column -bottom 60-
data_v2.isna().sum().tail(60)

# %%
# Drop columns with over 100,000 missing values
data_v3 = data_v2.drop(['member_id', 'desc', 'mths_since_last_delinq', 'mths_since_last_record', 'next_pymnt_d', 'mths_since_last_major_derog', 'annual_inc_joint', 'dti_joint', 'verification_status_joint', 'mths_since_recent_revol_delinq', 'num_tl_120dpd_2m', 'revol_bal_joint',
'sec_app_fico_range_low',
'sec_app_fico_range_high',
'sec_app_earliest_cr_line',
'sec_app_inq_last_6mths',
'sec_app_mort_acc',
'sec_app_open_acc',
'sec_app_revol_util',
'sec_app_open_act_il',
'sec_app_num_rev_accts',
'sec_app_chargeoff_within_12_mths',
'sec_app_collections_12_mths_ex_med',
'sec_app_mths_since_last_major_derog',
'hardship_type',
'hardship_reason',
'hardship_status',
'deferral_term',
'hardship_amount',
'hardship_start_date',
'hardship_end_date',
'payment_plan_start_date',
'hardship_length',
'hardship_dpd',
'hardship_loan_status',
'orig_projected_additional_accrued_interest',
'hardship_payoff_balance_amount',
'hardship_last_payment_amount',
'debt_settlement_flag_date',
'settlement_status',
'settlement_date',
'settlement_amount',
'settlement_percentage',
'settlement_term', 'open_acc_6m',
'open_act_il',
'open_il_12m',
'open_il_24m',
'mths_since_rcnt_il',
'total_bal_il',
'il_util',
'open_rv_12m',
'open_rv_24m',
'max_bal_bc',
'all_util',
'total_rev_hi_lim',
'inq_fi',
'total_cu_tl',
'inq_last_12m',
'mo_sin_old_il_acct',
'mths_since_recent_bc_dlq',
'mths_since_recent_inq'], axis=1)
data_v3
# Out:
#                                                        id  loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment grade sub_grade             emp_title emp_length home_ownership  annual_inc verification_status   issue_d  loan_status pymnt_plan  \
# 0                                                68407277     3600.0       3600.0           3600.0   36 months     13.99       123.03     C        C4               leadman  10+ years       MORTGAGE     55000.0        Not Verified  Dec-2015   Fully Paid          n
# 1                                                68355089    24700.0      24700.0          24700.0   36 months     11.99       820.28     C        C1              Engineer  10+ years       MORTGAGE     65000.0        Not Verified  Dec-2015   Fully Paid          n
# ...

# %%
# Drop columns with duplicate loan data, un-usable text & date columns and LC grade/sub-grade scores/int_rate, state & zip
data_v4 = data_v3.drop(['funded_amnt',
'funded_amnt_inv', 
'grade',
'sub_grade',
'url',
'purpose',
'title',
'fico_range_high',
'out_prncp_inv',
'total_pymnt_inv',
'last_pymnt_amnt',
'last_fico_range_high',
'last_fico_range_low',
'policy_code',
'delinq_amnt',
'hardship_flag',
'disbursement_method',
'debt_settlement_flag', 
'emp_title', 
'pymnt_plan', 
'initial_list_status', 
'out_prncp', 
'total_pymnt', 
'total_rec_prncp', 
'total_rec_int', 
'total_rec_late_fee', 
'recoveries', 
'collection_recovery_fee', 
'last_pymnt_d', 
'last_credit_pull_d',
'zip_code', 
'addr_state',
'int_rate',
'installment', 'term', 'emp_length', 'home_ownership', 'verification_status', 'issue_d', 'earliest_cr_line', 'application_type'], axis=1)
data_v4
# Out:
#                                                        id  loan_amnt  annual_inc  loan_status    dti  delinq_2yrs  fico_range_low  inq_last_6mths  open_acc  pub_rec  revol_bal  revol_util  total_acc  collections_12_mths_ex_med  acc_now_delinq  tot_coll_amt  tot_cur_bal  acc_open_past_24mths  \
# 0                                                68407277     3600.0     55000.0   Fully Paid   5.91          0.0           675.0             1.0       7.0      0.0     2765.0        29.7       13.0                         0.0             0.0         722.0     144904.0                   4.0
# 1                                                68355089    24700.0     65000.0   Fully Paid  16.06          1.0           715.0             4.0      22.0      0.0    21470.0        19.2       38.0                         0.0             0.0           0.0     204396.0                   4.0
# ...

# %%
#Drop "na"
data_v5 = data_v4.dropna()
data_v5
# Out:
#                id  loan_amnt  annual_inc  loan_status    dti  delinq_2yrs  fico_range_low  inq_last_6mths  open_acc  pub_rec  revol_bal  revol_util  total_acc  collections_12_mths_ex_med  acc_now_delinq  tot_coll_amt  tot_cur_bal  acc_open_past_24mths  avg_cur_bal  bc_open_to_buy  bc_util  \
# 0        68407277     3600.0     55000.0   Fully Paid   5.91          0.0           675.0             1.0       7.0      0.0     2765.0        29.7       13.0                         0.0             0.0         722.0     144904.0                   4.0      20701.0          1506.0     37.2
# 1        68355089    24700.0     65000.0   Fully Paid  16.06          1.0           715.0             4.0      22.0      0.0    21470.0        19.2       38.0                         0.0             0.0           0.0     204396.0                   4.0       9733.0         57830.0     27.1
# ...

# %%
data_v5.describe()
# Out:
#           loan_amnt    annual_inc           dti   delinq_2yrs  fico_range_low  inq_last_6mths      open_acc       pub_rec     revol_bal    revol_util     total_acc  collections_12_mths_ex_med  acc_now_delinq  tot_coll_amt   tot_cur_bal  acc_open_past_24mths   avg_cur_bal  bc_open_to_buy  \
# count  1.262501e+06  1.262501e+06  1.262501e+06  1.262501e+06    1.262501e+06    1.262501e+06  1.262501e+06  1.262501e+06  1.262501e+06  1.262501e+06  1.262501e+06                1.262501e+06    1.262501e+06  1.262501e+06  1.262501e+06          1.262501e+06  1.262501e+06    1.262501e+06
# mean   1.458163e+04  7.674611e+04  1.850037e+01  3.246809e-01    6.954219e+02    6.465983e-01  1.174522e+01  2.242596e-01  1.647270e+04  5.181342e+01  2.515739e+01                1.803246e-02    5.287125e-03  2.482798e+02  1.412077e+05          4.716289e+00  1.338467e+04    1.021561e+04
# ...

# %%
data_v5.dtypes
# Out:
# id                             object
# loan_amnt                     float64
# term                           object
# emp_length                     object
# home_ownership                 object
# annual_inc                    float64
# verification_status            object
# issue_d                        object
# loan_status                    object
# dti                           float64
# delinq_2yrs                   float64
# earliest_cr_line               object
# fico_range_low                float64
# inq_last_6mths                float64
# open_acc                      float64
# pub_rec                       float64
# revol_bal                     float64
# revol_util                    float64
# total_acc                     float64
# collections_12_mths_ex_med    float64
# application_type               object
# acc_now_delinq                float64
# tot_coll_amt                  float64
# tot_cur_bal                   float64
# acc_open_past_24mths          float64
# ...

# %%
data_v5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1262501 entries, 0 to 2260697
# Data columns (total 48 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   id                          1262501 non-null  object
#  1   loan_amnt                   1262501 non-null  float64
#  2   annual_inc                  1262501 non-null  float64
#  3   loan_status                 1262501 non-null  object
#  4   dti                         1262501 non-null  float64
#  5   delinq_2yrs                 1262501 non-null  float64
#  6   fico_range_low              1262501 non-null  float64
#  7   inq_last_6mths              1262501 non-null  float64
#  8   open_acc                    1262501 non-null  float64
#  9   pub_rec                     1262501 non-null  float64
#  10  revol_bal                   1262501 non-null  float64
#  11  revol_util                  1262501 non-null  float64
# ...

# %%
data_v5.to_csv("loandata_small.csv.gz", 
           index=False, 
           compression="gzip")
